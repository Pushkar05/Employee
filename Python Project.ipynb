# %% [markdown]
# 1.Make a script to take 25 employee data id,name,gender,age,city,sal,exp,working for the company years? dynamic--input()
# Make 2 null values  in categories city,gender and salary ,exp all in different rows
# Handle these null by pandas

# %%
import pandas as pd
import csv
class Employee:


        def __init__(self):
            pass
        def getdata(self):
            
            print("\nEnter Employee Details\n")
            name1 = input("\n Name : -\n")           
            gender1 = input("\n Gender: -\n")
            age1 = input("\n Age: -\n")
            city1 = input("\n City : -: -\n")
            salary1 = input("\n Salary: -\n")
            exp1 = input("\n Experience: -\n")
            work_year1 = input("\n Working for company Year: -\n")
            #name = []
            #gender = []
            #age = []
            #city = []
            #salary = []
            #exp = []
            #work_year = []
            

            # Append Element 
            name.append(name1)                                      
            gender.append(gender1)
            age.append(age1)
            city.append(city1)
            salary.append(salary1)
            exp.append(exp1)
            work_year.append(work_year1)

            
            dict1 = {'Name':name,'gender':gender,'Age':age,'City':city,'Salary':salary,'Experience':exp,'Work Year':work_year}
            emp = pd.DataFrame(dict1)
            print(emp)
            emp
            
            with open('mycsvfile.csv','wb') as f:
                w = csv.writer(f)
                w.writerows(dict1.items())

            
        
        
    
        def showdata(self):
            
            emp = pd.DataFrame(self.dict1)
            print(emp)
            emp

            #print("Enter Employee Details")
            #print("\n Name : -\n")
            #print("\n Gender: -\n")
            #print("\n Age: -\n")
            #print("\n City : -: -\n")
            #print("\n Salary: -\n")
            #print("\n Experience: -\n")
            #print("\n Working for company Year: -\n")

name = []
gender = []
age = []
city = []
salary = []
exp = []
work_year = []


obj=Employee()
x=int(input("How Many Employee Details Do You Wnat to Enter"))
choice = 0
while choice < x:
    
        print("\n1. Enter Employee Detail\n2. Display Employee Details\n3. Exit")
    
        ch = int(input("Enter Your Choice"))
        if ch == 1:
            print(obj.getdata())
            
        elif ch ==2:
            print(obj.showdata())
        
        elif ch ==3:
            break
            
        else:
            print("Wrong choice")
# Out:
# How Many Employee Details Do You Wnat to Enter2
#
# 1. Enter Employee Detail
# 2. Display Employee Details
# 3. Exit
# Enter Your Choice1
#
# Enter Employee Details
#
#
#  Name : -
# sd
#
#  Gender: -
# ads
#
#  Age: -
# sd
#
#  City : -: -
# asd
#
#  Salary: -
# sdf
#
#  Experience: -
# sdf
#
#  Working for company Year: -
# df
#   Name gender Age City Salary Experience Work Year
# 0   sd    ads  sd  asd    sdf        sdf        df
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e242245705c9> in <module>
#      81         ch = int(input("Enter Your Choice"))
#      82         if ch == 1:
# ---> 83             print(obj.getdata())
#      84
#      85         elif ch ==2:
#
# <ipython-input-9-e242245705c9> in getdata(self)
#      42             with open('mycsvfile.csv','wb') as f:
#      43                 w = csv.writer(f)
# ...

# %% [markdown]
# 2.Random Password Generator  :
# Password must have
# capital,
# small,
# number,
# symbol,
# leng 8 plus generate  25 password for above employee?

# %%
import random
 
lowercase = 'abcdefghijklmnopqrstuvwxyz' # same as string.ascii_lowercase
uppercase = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ' # same as string.ascii_uppercase
digits = '0123456789'                    # same as string.digits
punctuation = '!"#$%&\'()*+,-./:;<=>?@[]^_{|}~' # like string.punctuation but without backslash \ nor grave `
 
allowed = lowercase + uppercase + digits + punctuation
 
visually_similar = 'Il1O05S2Z'
 
def new_password(length:int, readable=True) -> str:
    if length < 4:
        print("password length={} is too short,".format(length),
            "minimum length=4")
        return ''
    choice = random.SystemRandom().choice
    while True:
        password_chars = [
            choice(lowercase),
            choice(uppercase),
            choice(digits),
            choice(punctuation)
            ] + random.sample(allowed, length-4)
        if (not readable or 
                all(c not in visually_similar for c in password_chars)):
            random.SystemRandom().shuffle(password_chars)
            return ''.join(password_chars)
 
 
def password_generator(length, qty=25, readable=True):
    for i in range(qty):
        print(new_password(length, readable))
        
password_generator(8,25)
# Out:
# /Gh4,&}_
# |s(tFh.9
# 4rYT=69r
# b$T8W,#)
# C8u+(J.X
# GJ?4]!mQ
# g8X)'}8c
# dFN}z=b7
# h#HG*w8o
# $RAJe4j,
# ^p_[KUM6
# @ugYz9"'
# ^_)Nnu4P
# [']ab3zY
# qV*3#Cx3
# BCD=+_7y
# d7}VPmQ|
# MvL@.89F
# y_!44B[K
# %4}X;rfF
# oL9'78xJ
# 3Er{&Piy
# x!4F?P78
# 3K#q6!oA
# ng}-3#HN
